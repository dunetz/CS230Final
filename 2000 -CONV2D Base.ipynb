# %%
#from google.colab import drive

# %%
#drive.mount('/content/drive')

# %%
#import os
#os.chdir("/content/drive")

# %%
#cd My Drive

# %%
#cd CS230-master

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import time
# %matplotlib inline
# 
from sklearn.metrics import confusion_matrix, classification_report, cohen_kappa_score

# %%
import os; 
#work-around to allow import from directory on same level
os.sys.path.append(os.path.dirname(os.path.abspath('.')))
from input.DataLoader import DataLoader
from input.GenerateBatch import GenerateBatch
from model.Model3 import train_generator
# Out:
# Using TensorFlow backend.

# %%
from sklearn.preprocessing import MinMaxScaler
from keras import regularizers
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense,Dropout,Activation, Lambda
from keras.layers import Conv1D, Conv2D, MaxPooling1D, Flatten
from keras.layers import  MaxPooling1D, MaxPooling2D,Reshape, BatchNormalization
from keras.utils import to_categorical
from keras.metrics import categorical_crossentropy
from scipy.stats import linregress
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report, cohen_kappa_score
from keras.backend import transpose, permute_dimensions,squeeze
from keras.optimizers import Adam

# %%
# PARAMETERS AND COMMENTs
#
# Conv2D with 5bar target and 0-5.6-7 training/val
# standadize window
# no dropout or regularizaton
configs={}
configs['batch_size']=500

configs['sequence_length']=100
configs['epochs']=60
configs['learning_rate']=.001
configs['learning_rate_decay']=0
configs['opt']=Adam(lr=configs['learning_rate'],
                   decay=configs['learning_rate_decay'])
configs['save_dir']='saved_models'
configs['nflag']=True #standardize each window



traindays=[0,1,2,3,4,5] #training and val days to look at in dataset
valdays=[6,7]
colx=range(40)# columns to look at in dataset - 0-40 are LOB
#colx=np.concatenate([np.arange(20),86+np.arange(20)])
coly=147 # target 144-148 are 1,2,3,5,10
generate_files=False
print('trainday',traindays,'valdays',valdays,'colx',colx,'coly',coly)
print(configs)
# Out:
# trainday [0, 1, 2, 3, 4, 5] valdays [6, 7] colx range(0, 40) coly 147
# {'batch_size': 500, 'sequence_length': 100, 'epochs': 60, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'opt': <keras.optimizers.Adam object at 0x7f06b6586668>, 'save_dir': 'saved_models', 'nflag': True}

# %% [markdown]
# ### Generate data from zip files or retrieve from pkl files in directory

# %%
if generate_files==True:
  path='data/'
  d=DataLoader(path)
  traindf=d.get_days(traindays)
  trainoffset=d.get_stock_offset(traindays)
  valdf=d.get_days(valdays)
  valoffset=d.get_stock_offset(valdays)

  traindf.to_pickle("traindf.pkl")
  valdf.to_pickle("valdf.pkl")
  np.save("trainoffset",trainoffset)
  np.save("valoffset",valoffset)

else:
  traindf=pd.read_pickle('traindf.pkl')
  valdf=pd.read_pickle('valdf.pkl')
  trainoffset=np.load("trainoffset.npy")
  valoffset=np.load("valoffset.npy")

# Select X and Y training and dev data. Y is categorical
trainx=traindf.iloc[:,colx].values
trainy=to_categorical(traindf.iloc[:,coly].values-1)
valx=valdf.iloc[:,colx].values
valy=to_categorical(valdf.iloc[:,coly].values-1)

# %% [markdown]
# ### Build and compile model

# %%
model = Sequential()
model.add(Conv2D(16, kernel_size=(4, 40), strides=(1, 1),data_format='channels_last',activation='relu',
                 input_shape=(configs['sequence_length'],len(colx),1)))
model.add(Conv2D(16, kernel_size=(1,1),strides=(1,1),data_format='channels_last',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,1), strides=2))
model.add(Conv2D(32,kernel_size=(4,1), strides=(1,1),data_format='channels_last',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,1), strides=2))
model.add(Conv2D(32,kernel_size=(3,1), strides=(1,1),data_format='channels_last',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,1), strides=2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
#model.add(BatchNormalization(momentum=0.9))
#model.add(Dropout(0.50))
#model.add(Dense(64,kernel_regularizer=regularizers.l2(0.01),activation='relu'))
#model.add(Dropout(0.20))
model.add(Dense(3, activation='softmax'))
#
opt=Adam(lr=configs['learning_rate'],decay=configs['learning_rate_decay'])
model.compile(loss="categorical_crossentropy", optimizer=configs['opt'],metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 97, 1, 16)         2576
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 97, 1, 16)         272
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 48, 1, 16)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 45, 1, 32)         2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 1, 32)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 20, 1, 32)         3104
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 1, 32)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 320)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                20544
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 28,771
# Trainable params: 28,771
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Fitting

# %%
training_generator=GenerateBatch(trainx,trainy,trainoffset)
val_generator=GenerateBatch(valx,valy,valoffset)

# %%
# out-of memory generative training
steps_per_epoch=training_generator.epoch_size(configs['sequence_length'],
                                              configs['batch_size'])
steps_per_epoch_val=training_generator.epoch_size(configs['sequence_length'],
                                              configs['batch_size'])

# %%
# GenerateBatch2 contains logic to avoid running over stock/day divides
history=train_generator(
    model=model,
    train_gen=training_generator.GenerateBatch_conv(configs['sequence_length'],
                                               configs['batch_size'],
                                               configs['nflag']),
    val_gen=val_generator.GenerateBatch_conv(configs['sequence_length'],
                                        configs['batch_size'],
                                        configs['nflag']),
    epochs=configs['epochs'],
    batch_size=configs['batch_size'],
    steps_per_epoch=steps_per_epoch,
    validation_steps=steps_per_epoch_val,
    save_dir=configs['save_dir']
    )
# Out:
# [Model] Training Started
# [Model] 60 epochs, 500 batch size, 442.0 batches per epoch
# Epoch 1/60
#  - 69s - loss: 1.1039 - acc: 0.3402 - val_loss: 1.1015 - val_acc: 0.2915
# Epoch 2/60
#  - 13s - loss: 1.0992 - acc: 0.3396 - val_loss: 1.0978 - val_acc: 0.3659
# Epoch 3/60
#  - 12s - loss: 1.0985 - acc: 0.3491 - val_loss: 1.1029 - val_acc: 0.2661
# Epoch 4/60
#  - 12s - loss: 1.0978 - acc: 0.3517 - val_loss: 1.1016 - val_acc: 0.2858
# Epoch 5/60
#  - 13s - loss: 1.0972 - acc: 0.3558 - val_loss: 1.0951 - val_acc: 0.3507
# Epoch 6/60
#  - 12s - loss: 1.1064 - acc: 0.3465 - val_loss: 1.0879 - val_acc: 0.4577
# Epoch 7/60
#  - 12s - loss: 1.1003 - acc: 0.3487 - val_loss: 1.1055 - val_acc: 0.3093
# Epoch 8/60
#  - 13s - loss: 1.0986 - acc: 0.3441 - val_loss: 1.1074 - val_acc: 0.2743
# Epoch 9/60
#  - 12s - loss: 1.0986 - acc: 0.3438 - val_loss: 1.1049 - val_acc: 0.2704
# Epoch 10/60
#  - 12s - loss: 1.0981 - acc: 0.3346 - val_loss: 1.1046 - val_acc: 0.2849
# Epoch 11/60
#  - 13s - loss: 1.0985 - acc: 0.3372 - val_loss: 1.1098 - val_acc: 0.2724
# Epoch 12/60
#  - 12s - loss: 1.0979 - acc: 0.3457 - val_loss: 1.1045 - val_acc: 0.2815
# Epoch 13/60
#  - 13s - loss: 1.0954 - acc: 0.3541 - val_loss: 1.1031 - val_acc: 0.3140
# Epoch 14/60
#  - 13s - loss: 1.0956 - acc: 0.3528 - val_loss: 1.1025 - val_acc: 0.3055
# Epoch 15/60
#  - 12s - loss: 1.0935 - acc: 0.3603 - val_loss: 1.0920 - val_acc: 0.4144
# Epoch 16/60
#  - 13s - loss: 1.0938 - acc: 0.3626 - val_loss: 1.0873 - val_acc: 0.3955
# Epoch 17/60
#  - 12s - loss: 1.0913 - acc: 0.3673 - val_loss: 1.1085 - val_acc: 0.2837
# Epoch 18/60
#  - 12s - loss: 1.0904 - acc: 0.3662 - val_loss: 1.0915 - val_acc: 0.4178
# Epoch 19/60
#  - 13s - loss: 1.0876 - acc: 0.3717 - val_loss: 1.0977 - val_acc: 0.3228
# Epoch 20/60
#  - 13s - loss: 1.0854 - acc: 0.3766 - val_loss: 1.0981 - val_acc: 0.3606
# Epoch 21/60
#  - 13s - loss: 1.0843 - acc: 0.3781 - val_loss: 1.0760 - val_acc: 0.4103
# Epoch 22/60
#  - 12s - loss: 1.0827 - acc: 0.3850 - val_loss: 1.0848 - val_acc: 0.3906
# Epoch 23/60
#  - 12s - loss: 1.0847 - acc: 0.3819 - val_loss: 1.0826 - val_acc: 0.4106
# Epoch 24/60
#  - 12s - loss: 1.0789 - acc: 0.3890 - val_loss: 1.0743 - val_acc: 0.4273
# Epoch 25/60
#  - 13s - loss: 1.0766 - acc: 0.3957 - val_loss: 1.0868 - val_acc: 0.4098
# Epoch 26/60
#  - 12s - loss: 1.0743 - acc: 0.3983 - val_loss: 1.1015 - val_acc: 0.3380
# Epoch 27/60
#  - 12s - loss: 1.0730 - acc: 0.3996 - val_loss: 1.0791 - val_acc: 0.4304
# Epoch 28/60
#  - 12s - loss: 1.0678 - acc: 0.4071 - val_loss: 1.0942 - val_acc: 0.4075
# Epoch 29/60
#  - 13s - loss: 1.0631 - acc: 0.4145 - val_loss: 1.1037 - val_acc: 0.4077
# Epoch 30/60
#  - 13s - loss: 1.0583 - acc: 0.4179 - val_loss: 1.1123 - val_acc: 0.4136
# Epoch 31/60
#  - 12s - loss: 1.0538 - acc: 0.4275 - val_loss: 1.1222 - val_acc: 0.3969
# Epoch 32/60
#  - 12s - loss: 1.0480 - acc: 0.4337 - val_loss: 1.1244 - val_acc: 0.4002
# Epoch 33/60
#  - 12s - loss: 1.0456 - acc: 0.4339 - val_loss: 1.1259 - val_acc: 0.4223
# Epoch 34/60
#  - 13s - loss: 1.0366 - acc: 0.4444 - val_loss: 1.1488 - val_acc: 0.4040
# Epoch 35/60
#  - 13s - loss: 1.0295 - acc: 0.4489 - val_loss: 1.1637 - val_acc: 0.4094
# Epoch 36/60
#  - 12s - loss: 1.0238 - acc: 0.4538 - val_loss: 1.1859 - val_acc: 0.4167
# Epoch 37/60
#  - 12s - loss: 1.0177 - acc: 0.4583 - val_loss: 1.1801 - val_acc: 0.4066
# Epoch 38/60
#  - 13s - loss: 1.0110 - acc: 0.4627 - val_loss: 1.1780 - val_acc: 0.4137
# Epoch 39/60
#  - 12s - loss: 1.0068 - acc: 0.4656 - val_loss: 1.2031 - val_acc: 0.4024
# Epoch 40/60
#  - 12s - loss: 1.0024 - acc: 0.4691 - val_loss: 1.1897 - val_acc: 0.4024
# Epoch 41/60
#  - 13s - loss: 0.9992 - acc: 0.4721 - val_loss: 1.1953 - val_acc: 0.4125
# Epoch 42/60
#  - 12s - loss: 0.9926 - acc: 0.4770 - val_loss: 1.2054 - val_acc: 0.4175
# Epoch 43/60
#  - 12s - loss: 0.9941 - acc: 0.4733 - val_loss: 1.2319 - val_acc: 0.3999
# Epoch 44/60
#  - 12s - loss: 0.9892 - acc: 0.4787 - val_loss: 1.2269 - val_acc: 0.4138
# Epoch 45/60
#  - 13s - loss: 0.9873 - acc: 0.4810 - val_loss: 1.2305 - val_acc: 0.4155
# Epoch 46/60
#  - 12s - loss: 0.9832 - acc: 0.4817 - val_loss: 1.2395 - val_acc: 0.4047
# Epoch 47/60
#  - 12s - loss: 0.9802 - acc: 0.4851 - val_loss: 1.2453 - val_acc: 0.4203
# Epoch 48/60
#  - 13s - loss: 0.9781 - acc: 0.4886 - val_loss: 1.2666 - val_acc: 0.4058
# Epoch 49/60
#  - 12s - loss: 0.9777 - acc: 0.4881 - val_loss: 1.2681 - val_acc: 0.3642
# Epoch 50/60
#  - 13s - loss: 0.9785 - acc: 0.4877 - val_loss: 1.2786 - val_acc: 0.4024
# Epoch 51/60
#  - 13s - loss: 0.9753 - acc: 0.4893 - val_loss: 1.3006 - val_acc: 0.4030
# Epoch 52/60
#  - 12s - loss: 0.9689 - acc: 0.4951 - val_loss: 1.3087 - val_acc: 0.3482
# Epoch 53/60
#  - 12s - loss: 0.9672 - acc: 0.4953 - val_loss: 1.2823 - val_acc: 0.3983
# Epoch 54/60
#  - 12s - loss: 0.9634 - acc: 0.4982 - val_loss: 1.3295 - val_acc: 0.3950
# Epoch 55/60
#  - 12s - loss: 0.9608 - acc: 0.4998 - val_loss: 1.3456 - val_acc: 0.3830
# Epoch 56/60
#  - 12s - loss: 0.9596 - acc: 0.4999 - val_loss: 1.3004 - val_acc: 0.3786
# Epoch 57/60
#  - 13s - loss: 0.9573 - acc: 0.5026 - val_loss: 1.3494 - val_acc: 0.3635
# Epoch 58/60
#  - 13s - loss: 0.9583 - acc: 0.4995 - val_loss: 1.3284 - val_acc: 0.3797
# Epoch 59/60
#  - 13s - loss: 0.9543 - acc: 0.5037 - val_loss: 1.3250 - val_acc: 0.3901
# Epoch 60/60
#  - 12s - loss: 0.9516 - acc: 0.5079 - val_loss: 1.3865 - val_acc: 0.3807
# [Model] Training Completed. Model saved as saved_models/05122018-192938-e60.h5
# Time taken: 0:13:26.524689

# %%
#from keras.models import load_model
#model = load_model('saved_models/04122018-125307-e20.h5')

# %%
plt.figure(figsize=(15,5))
plt.plot(history.history['loss'],'b--',lw=2,label='train_loss')
plt.plot(history.history['val_loss'],'g-',lw=2,label='val_loss')
plt.legend()
plt.ylim([.5,1.3])
plt.xlabel('Epochs')
plt.ylabel('Cost')
# Out:
# Text(0,0.5,'Cost')

# %%
# make our predictions - start from beginning
train_gen=training_generator.GenerateBatch_conv(configs['sequence_length'],configs['batch_size'],configs['nflag'])
val_gen=val_generator.GenerateBatch_conv(configs['sequence_length'],configs['batch_size'],configs['nflag'])

# %%
y_train=[]
yhat_train=[]
y_val=[]
yhat_val=[]

# %%
# predict using same sequence lengths and batches as in training
for i in range(int(steps_per_epoch)):
    dat=next(train_gen)
    y_train.append(dat[1])
    yhat_train.append(model.predict(dat[0]))
for i in range(int(steps_per_epoch_val)):
    dat=next(val_gen)
    y_val.append(dat[1])
    yhat_val.append(model.predict(dat[0]))

# %%
burn_in=0 # drop early predictions 
y_train=np.concatenate(y_train).reshape(-1,3)[burn_in:]
yhat_train=np.concatenate(yhat_train).reshape(-1,3)[burn_in:]
y_val=np.concatenate(y_val).reshape(-1,3)[burn_in:]
yhat_val=np.concatenate(yhat_val).reshape(-1,3)[burn_in:]

# %% [markdown]
# ### Training and Validation Performance

# %%
# How well have we done on training data
print ("Training ")
Y=np.argmax(y_train,axis=1)
Yhat=np.argmax(yhat_train,axis=1)
c=confusion_matrix(Y,Yhat)
c=np.concatenate((c,np.sum(c,axis=1).reshape(-1,1)),axis=1)
c=np.concatenate((c,np.sum(c,axis=0).reshape(1,-1)),axis=0)
print(c)
print(classification_report(Yhat,Y))
print("cohen kappa score:",cohen_kappa_score(Yhat,Y))
# How well have we done on test data
print("Test ")
Y=np.argmax(y_val,axis=1)
Yhat=np.argmax(yhat_val,axis=1)
c=confusion_matrix(Y,Yhat)
c=np.concatenate((c,np.sum(c,axis=1).reshape(-1,1)),axis=1)
c=np.concatenate((c,np.sum(c,axis=0).reshape(1,-1)),axis=0)
print(c)
print(classification_report(Yhat,Y))
print("cohen kappa score:",cohen_kappa_score(Yhat,Y))
# Out:
# Training
# [[ 23015  24265  25919  73199]
#  [ 12850  36439  19539  68828]
#  [ 16251  22969  33187  72407]
#  [ 52116  83673  78645 214434]]
#              precision    recall  f1-score   support
#
#           0       0.31      0.44      0.37     52116
#           1       0.53      0.44      0.48     83673
#           2       0.46      0.42      0.44     78645
#
# avg / total       0.45      0.43      0.44    214434
#
# cohen kappa score: 0.14967461406330185
# Test
# [[ 16386  24910  25196  66492]
#  [ 17579  41404  27406  86389]
#  [ 15970  22100  23776  61846]
#  [ 49935  88414  76378 214727]]
#              precision    recall  f1-score   support
#
#           0       0.25      0.33      0.28     49935
#           1       0.48      0.47      0.47     88414
#           2       0.38      0.31      0.34     76378
#
# avg / total       0.39      0.38      0.38    214727
#
# cohen kappa score: 0.06022775086111376

# %% [markdown]
# ### Visualize Filters using Gradient Ascent

# %%
import keras.backend as K

# %%
layer_dict=dict([(layer.name,layer) for layer in model.layers[1::]])
input_img=model.input

# %%
def normalize(x):
     return x/(K.sqrt(K.mean(K.square(x)))+K.epsilon())

# %%
layer_name='conv2d_4'
n=64

# %%
kept_filters=[]
for filter_index in range(n):
    layer_output=layer_dict[layer_name].output
    loss=K.mean(layer_output[:,filter_index:,:])
    grads=K.gradients(loss,input_img)[0]
    grads=normalize(grads)
    iterate=K.function([input_img],[loss,grads])
    step=1
    input_img_data=np.random.random((1,100,40,1))
    for i in range(40):
        loss_value,grad_values=iterate([input_img_data])
        input_img_data +=grad_values*step
    print('Filter: %d, Final loss value:%.2f' % (filter_index,loss_value))
    if loss_value >0:
        kept_filters.append((input_img_data[0],loss_value))
print(len(kept_filters))
# Out:
# Filter: 0, Final loss value:224.37
# Filter: 1, Final loss value:261.06
# Filter: 2, Final loss value:253.91
# Filter: 3, Final loss value:269.19
# Filter: 4, Final loss value:244.96
# Filter: 5, Final loss value:266.28
# Filter: 6, Final loss value:312.06
# Filter: 7, Final loss value:242.69
# Filter: 8, Final loss value:290.12
# Filter: 9, Final loss value:277.88
# Filter: 10, Final loss value:350.59
# Filter: 11, Final loss value:364.82
# Filter: 12, Final loss value:317.45
# Filter: 13, Final loss value:376.58
# Filter: 14, Final loss value:437.46
# Filter: 15, Final loss value:438.00
# Filter: 16, Final loss value:430.87
# Filter: 17, Final loss value:666.99
# Filter: 18, Final loss value:577.21
# Filter: 19, Final loss value:965.58
# Filter: 20, Final loss value:nan
# Filter: 21, Final loss value:nan
# Filter: 22, Final loss value:nan
# Filter: 23, Final loss value:nan
# Filter: 24, Final loss value:nan
# Filter: 25, Final loss value:nan
# Filter: 26, Final loss value:nan
# Filter: 27, Final loss value:nan
# Filter: 28, Final loss value:nan
# Filter: 29, Final loss value:nan
# Filter: 30, Final loss value:nan
# Filter: 31, Final loss value:nan
# Filter: 32, Final loss value:nan
# Filter: 33, Final loss value:nan
# Filter: 34, Final loss value:nan
# Filter: 35, Final loss value:nan
# Filter: 36, Final loss value:nan
# Filter: 37, Final loss value:nan
# Filter: 38, Final loss value:nan
# Filter: 39, Final loss value:nan
# Filter: 40, Final loss value:nan
# Filter: 41, Final loss value:nan
# Filter: 42, Final loss value:nan
# Filter: 43, Final loss value:nan
# Filter: 44, Final loss value:nan
# Filter: 45, Final loss value:nan
# Filter: 46, Final loss value:nan
# Filter: 47, Final loss value:nan
# Filter: 48, Final loss value:nan
# Filter: 49, Final loss value:nan
# Filter: 50, Final loss value:nan
# Filter: 51, Final loss value:nan
# Filter: 52, Final loss value:nan
# Filter: 53, Final loss value:nan
# Filter: 54, Final loss value:nan
# Filter: 55, Final loss value:nan
# Filter: 56, Final loss value:nan
# Filter: 57, Final loss value:nan
# Filter: 58, Final loss value:nan
# Filter: 59, Final loss value:nan
# Filter: 60, Final loss value:nan
# Filter: 61, Final loss value:nan
# Filter: 62, Final loss value:nan
# Filter: 63, Final loss value:nan
# 20

# %%
len(kept_filters)
# Out:
# 20

# %%
f0=kept_filters[0]

# %%
f0[1]
# Out:
# 224.37402

# %%
f0[0].shape
# Out:
# (100, 40, 1)

# %%
img=f0[0]

# %%
img.shape
# Out:
# (100, 40, 1)

# %%
plt.figure(figsize=(15,10))
plt.suptitle("How filters visualize the first three price levels",fontsize=12)
for i,f in enumerate(kept_filters[:16]):
    img=f[0][:,:,0]
    plt.subplot(4,4,i+1)
    plt.plot(img[range(0,100)][:,[0,2,4,6,8,10]])

# %%
plt.figure(figsize=(15,10))
plt.suptitle("How filters visualize the first three price levels",fontsize=12)
for i,f in enumerate(kept_filters[:16]):
    img=f[0][:,:,0]
    plt.subplot(4,4,i+1)
    plt.plot(img[range(0,100)][:,[1,3,5,7,9,11,13]])

# %%
# visualize one layer across all 16 filters
import matplotlib.pylab as plt
# %matplotlib inline
plt.figure(figsize=(5,5))
plt.title("Inside Ask Across 16 filters")
for f in kept_filters[:16]:
    img=f[0][:,:,0]
    plt.plot(img[range(0,100)][:,0])

# %% [markdown]
# ###  Find highest predictions for each category in each batch. Plot highest values

# %%
dn, sm, up = [],[],[]

# find the highest scoring input for each categorical output category in each batch
# make our predictions - start from beginning
train_gen=training_generator.GenerateBatch_conv(configs['sequence_length'],configs['batch_size'],configs['nflag'])
for i in range(int(steps_per_epoch)):
    dat=next(train_gen)[0]
    yhat=model.predict(dat)
    #
    dn.append(dat[np.argmax(yhat[:,0])])
    sm.append(dat[np.argmax(yhat[:,1])])
    up.append(dat[np.argmax(yhat[:,2])])

# %%
dnavg=np.average(np.array(dn),axis=0)
upavg=np.average(np.array(up),axis=0)

# %%
t=np.array([0])
plt.figure(figsize=(20,5))
plt.suptitle("Up predictions")
plt.subplot(1,4,1)
_=plt.plot(upavg[:,t,0])
plt.title('price:ask')
plt.subplot(1,4,2)
_=plt.plot(upavg[:,t+2,0])
plt.title('price:bid')
plt.subplot(1,4,3)
_=plt.plot(upavg[:, t+1,0])
plt.title('vol:ask')
plt.subplot(1,4,4)
_=plt.plot(upavg[:,t+3,0])
_=plt.title('vol:bid')

# %%
plt.figure(figsize=(20,5))
plt.suptitle("Down prediction")
plt.subplot(1,4,1)
_=plt.plot(dnavg[:,t,0])
plt.title('price:ask')
plt.subplot(1,4,2)
_=plt.plot(dnavg[:,t+2,0])
plt.title('price:bid')
plt.subplot(1,4,3)
_=plt.plot(dnavg[:, t+1,0])
plt.title('vol;ask')
plt.subplot(1,4,4)
_=plt.plot(dnavg[:,t+3,0])
_=plt.title('vol:bid')

# %% [markdown]
# ### Perform Gradient Ascent on each category (final softmax layer) to generate input with strongest signal.

# %%
#visualize
ylabel=[]
layer_name='dense_2' #final layer - categorical
layer_output=layer_dict[layer_name].output
print(layer_output.shape)
for i in range(3):
    print('processing label %d' % i)
    loss=layer_output[:,i] #want to increase value of label i
    #loss=K.mean(layer_output[:,filter_index:,:])
    grads=K.gradients(loss,input_img)[0]
    grads=normalize(grads)
    iterate=K.function([input_img],[loss,grads])
    step=1
    input_img_data=np.random.random((1,100,40,1))
    for j in range(1000):
        loss_value,grad_values=iterate([input_img_data])
        input_img_data +=grad_values*step
        #print('Current loss values:', loss_value)
    print(loss_value)
    ylabel.append((input_img_data[0],loss_value))
# Out:
# (?, 3)
# processing label 0
# [1.]
# processing label 1
# [1.]
# processing label 2
# [1.]

# %%
y=ylabel[0][0]

t=np.array([0])
#
y=ylabel[0][0]
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.title('Generated Image for inside bid/ask for Down Prediction')
plt.plot(y[:,t,0])
plt.plot(y[:,t+4,0])
#
y=ylabel[2][0]
plt.subplot(1,2,2)
plt.title(' Generated Image for inside bid/ask for Up Prediction')
plt.plot(y[:,t,0])
plt.plot(y[:,t+4,0])
y=ylabel[0][0]
